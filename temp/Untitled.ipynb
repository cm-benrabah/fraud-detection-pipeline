# %%
import pandas as pd
from sdv.tabular import CTGAN, GaussianCopula

# Load your Paysim dataset
df = pd.read_csv(r'D:\PS_20174392719_1491204439457_log.csv\PS_20174392719_1491204439457_log.csv')

# Train the SDV model (CTGAN for deep learning-based generation)
model = GaussianCopula()
model.fit(df)

# Optionally, save the trained model for future use
model.save('trained_GaussianCopula_model.pkl')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8373c0ac9afb> in <module>
#       7 # Train the SDV model (CTGAN for deep learning-based generation)
#       8 model = GaussianCopula()
# ----> 9 model.fit(df)
#      10
#      11 # Optionally, save the trained model for future use
#
# ~\anaconda3\envs\paysim_3.6\lib\site-packages\sdv\tabular\base.py in fit(self, data)
#     137                      self._metadata.name, data.shape)
#     138         if not self._metadata_fitted:
# --> 139             self._metadata.fit(data)
#     140
#     141         self._num_rows = len(data)
#
# ~\anaconda3\envs\paysim_3.6\lib\site-packages\sdv\metadata\table.py in fit(self, data)
#     635
#     636         LOGGER.info('Fitting HyperTransformer for table %s', self.name)
# --> 637         self._fit_hyper_transformer(constrained, extra_columns)
#     638         self.fitted = True
#     639
#
# ~\anaconda3\envs\paysim_3.6\lib\site-packages\sdv\metadata\table.py in _fit_hyper_transformer(self, data, extra_columns)
#     529         fit_columns = list(dtypes)
#     530         if not data[fit_columns].empty:
# --> 531             self._hyper_transformer.fit(data[fit_columns])
#     532
#     533     @staticmethod
#
# ~\anaconda3\envs\paysim_3.6\lib\site-packages\rdt\hyper_transformer.py in fit(self, data)
#     717         self._input_columns = list(data.columns)
#     718         for field in self._input_columns:
# --> 719             data = self._fit_field_transformer(data, field, self.field_transformers[field])
#     720
#     721         self._validate_all_fields_fitted()
#
# ~\anaconda3\envs\paysim_3.6\lib\site-packages\rdt\hyper_transformer.py in _fit_field_transformer(self, data, field, transformer)
#     652             self._add_field_to_set(field, self._fitted_fields)
#     653             self._transformers_sequence.append(transformer)
# --> 654             data = transformer.transform(data)
#     655
#     656             output_sdtypes = transformer.get_output_sdtypes()
#
# ~\anaconda3\envs\paysim_3.6\lib\site-packages\rdt\transformers\base.py in transform(self, data, drop)
#     275
#     276         columns_data = self._get_columns_data(data, self.columns)
# --> 277         transformed_data = self._transform(columns_data)
#     278
#     279         data = self._add_columns_to_data(data, transformed_data, self.output_columns)
#
# ~\anaconda3\envs\paysim_3.6\lib\site-packages\rdt\transformers\categorical.py in _transform(self, data)
#     194         data[unseen_indexes] = np.random.choice(fit_categories, size=unseen_indexes.size)
#     195         if len(self.means) < len(data):
# --> 196             return self._transform_by_category(data)
#     197
#     198         return self._transform_by_row(data)
#
# ~\anaconda3\envs\paysim_3.6\lib\site-packages\rdt\transformers\categorical.py in _transform_by_category(self, data)
#     144                 mask = (data.to_numpy() == category)
#     145
# --> 146             if self.add_noise:
#     147                 result[mask] = norm.rvs(mean, std, size=mask.sum())
#     148                 result[mask] = self._clip_noised_transform(result[mask], start, end)
#
# KeyboardInterrupt:
